# %%
#orders = pd.read_csv("D:/DiscountMate/instacart_data/orders.csv")
orders = pd.read_csv("/content/orders.csv")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
orders["day_hour"] = [f"{day}-{hour}" for day,hour in zip(orders["order_dow"],orders["order_hour_of_day"])]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
orders["user_day"] = [f"{user}-{day}" for user,day in zip(orders["user_id"],orders["order_dow"])]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
orders = orders[orders["eval_set"]=="prior"]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#order_products = pd.read_csv("D:/DiscountMate/instacart_data/order_products__prior.csv")
order_products = pd.read_csv("/content/order_products__prior.csv")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df = pd.merge(orders,order_products, how="inner", on="order_id")[["order_id","user_id","product_id","day_hour","user_day"]]
df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    order_id  user_id  product_id day_hour user_day
# 0    473747        1         196     3-12      1-3
# 1    473747        1       12427     3-12      1-3
# 2    473747        1       10258     3-12      1-3
# 3    473747        1       25133     3-12      1-3
# 4    473747        1       30450     3-12      1-3

# %%
df["product_id"].value_counts()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# product_id
# 24852    112793
# 13176     90131
# 21137     63228
# 21903     57246
# 47209     50788
#           ...
# 30029         1
# 23187         1
# 18504         1
# 9667          1
# 43145         1
# Name: count, Length: 47802, dtype: int64

# %%
df["product_id"].value_counts().mean()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 161.3436885485963

# %%
import statsmodels.stats.api as sms
low_conf, up_conf = sms.DescrStatsW(df["product_id"].value_counts()).tconfint_mean()
print(f"Lower Confidence Interval: {low_conf:.0f}")
print(f"Upper Confidence Interval: {up_conf:.0f}")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Lower Confidence Interval: 151
# Upper Confidence Interval: 172

# %%
important_products = df["product_id"].value_counts()[df["product_id"].value_counts() > low_conf].index
important_products
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Index([24852, 13176, 21137, 21903, 47209, 47766, 47626, 16797, 26209, 27845,
#        ...
#        33942,  7695, 43460, 48790,  1073,  7480, 32982, 19571,  9346,  3107],
#       dtype='int64', name='product_id', length=7031)

# %%
df["user_id"].value_counts()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# user_id
# 176478    974
# 52008     906
# 160106    890
# 74315     758
# 142131    736
#          ...
# 185197      1
# 81025       1
# 123800      1
# 52908       1
# 167146      1
# Name: count, Length: 176729, dtype: int64

# %%
df = df[df["product_id"].isin(important_products)]
df.shape
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (6680625, 5)

# %%
df["product_id"].value_counts()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# product_id
# 24852    112793
# 13176     90131
# 21137     63228
# 21903     57246
# 47209     50788
#           ...
# 3107        151
# 10275       151
# 39975       151
# 5063        151
# 33942       151
# Name: count, Length: 7031, dtype: int64

# %%
low_conf, up_conf = sms.DescrStatsW(df["user_id"].value_counts()).tconfint_mean()
print(f"Lower Confidence Interval: {low_conf:.0f}")
print(f"Upper Confidence Interval: {up_conf:.0f}")
# Out:
# Lower Confidence Interval: 38
# Upper Confidence Interval: 38
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
important_baskets = df["user_id"].value_counts()[df["user_id"].value_counts() > low_conf].index
important_baskets
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Index([176478,  52008, 160106, 142131,  79106,   6710,  17738, 189425,  74680,
#        201268,
#        ...
#        173816,  35926,  13178, 128127,  35497, 117633,   3976, 109700,  21899,
#        191935],
#       dtype='int64', name='user_id', length=54394)

# %%
df = df[df["user_id"].isin(important_baskets)]
df.shape
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (4900725, 5)

# %%
df["user_id"].value_counts()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# user_id
# 176478    853
# 52008     829
# 160106    805
# 142131    709
# 6710      672
#          ...
# 21592      38
# 102547     38
# 102457     38
# 201524     38
# 139367     38
# Name: count, Length: 54394, dtype: int64

# %%
basket = df.groupby(["user_id","product_id"])["order_id"].count().unstack().notnull()
basket
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# product_id  1      10     23     25     28     34     37     45     49     \
# user_id
# 7           False  False  False  False  False  False  False  False  False
# 10          False  False  False  False  False  False  False  False  False
# 17          False  False  False  False  False  False  False  False  False
# 19          False  False  False  False  False  False  False  False  False
# 21          False  False  False  False  False  False  False  False  False
# ...           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 206202      False  False  False  False  False  False  False  False  False
# 206203      False  False  False  False  False  False  False  False  False
# 206206      False  False  False  False  False  False  False  False  False
# 206208      False  False  False  False  False  False  False  False  False
# 206209      False  False  False  False  False  False  False  False  False
#
# product_id  54     ...  49610  49615  49621  49628  49640  49644  49655  \
# user_id            ...
# 7           False  ...  False  False  False  False  False  False  False
# 10          False  ...  False  False  False  False  False  False  False
# 17          False  ...  False  False  False  False  False  False  False
# 19          False  ...  False  False  False  False  False  False  False
# 21          False  ...  False  False  False  False  False  False  False
# ...           ...  ...    ...    ...    ...    ...    ...    ...    ...
# 206202      False  ...  False  False  False  False  False  False  False
# 206203      False  ...  False  False  False  False  False  False  False
# 206206      False  ...  False  False  False  False  False  False  False
# 206208      False  ...  False  False  False  False  False  False  False
# 206209      False  ...  False  False  False  False  False  False  False
#
# product_id  49667  49680  49683
# user_id
# 7           False  False  False
# 10          False  False  False
# 17          False  False  False
# 19          False  False  False
# 21          False  False  False
# ...           ...    ...    ...
# 206202      False  False   True
# 206203      False  False  False
# 206206      False  False  False
# 206208      False  False  False
# 206209      False  False  False
#
# [54394 rows x 7031 columns]

# %%
from mlxtend.frequent_patterns import apriori, association_rules
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
frequent_itemsets = apriori(basket,min_support=0.07,use_colnames=True,verbose=1)
frequent_itemsets.sort_values("support", ascending=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Processing 24 combinations | Sampling itemset size 4
#       support        itemsets
# 27   0.429404         (24852)
# 12   0.372081         (13176)
# 19   0.367596         (21137)
# 21   0.321212         (21903)
# 71   0.287936         (47209)
# ..        ...             ...
# 109  0.071037  (27104, 21137)
# 153  0.070614  (26209, 31717)
# 158  0.070504  (47209, 39275)
# 86   0.070375   (8518, 21903)
# 135  0.070173  (45007, 22935)
#
# [168 rows x 2 columns]

# %%
rules = association_rules(frequent_itemsets,metric="support",min_threshold=0.02)
rules.sort_values(by="lift")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#     antecedents     consequents  antecedent support  consequent support  \
# 26      (13176)         (24852)            0.372081            0.429404
# 27      (24852)         (13176)            0.429404            0.372081
# 136     (47209)         (24852)            0.287936            0.429404
# 137     (24852)         (47209)            0.429404            0.287936
# 110     (24852)         (22935)            0.429404            0.206236
# ..          ...             ...                 ...                 ...
# 181     (27966)  (13176, 21137)            0.202743            0.182814
# 153     (31717)         (26209)            0.141063            0.249862
# 152     (26209)         (31717)            0.249862            0.141063
# 113     (22935)         (24964)            0.206236            0.208902
# 112     (24964)         (22935)            0.208902            0.206236
#
#       support  confidence      lift  leverage  conviction  zhangs_metric
# 26   0.097272    0.261426  0.608811 -0.062502    0.772564      -0.505756
# 27   0.097272    0.226527  0.608811 -0.062502    0.811817      -0.529654
# 136  0.105214    0.365407  0.850963 -0.018427    0.899152      -0.197407
# 137  0.105214    0.245023  0.850963 -0.018427    0.943160      -0.234855
# 110  0.077876    0.181359  0.879376 -0.010682    0.969612      -0.193807
# ..        ...         ...       ...       ...         ...            ...
# 181  0.073317    0.361625  1.978100  0.036253    1.280103       0.620207
# 153  0.070614    0.500586  2.003451  0.035368    1.502038       0.583118
# 152  0.070614    0.282613  2.003451  0.035368    1.197314       0.667692
# 113  0.092915    0.450526  2.156641  0.049832    1.439737       0.675662
# 112  0.092915    0.444777  2.156641  0.049832    1.429631       0.677938
#
# [206 rows x 10 columns]

# %%
random_product = rules.sample(1,random_state=100)["antecedents"].explode().iloc[0]
random_product
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 27966

# %%
lime  = 26209
banana = 24852
chocolatesandwichbiscuit = 1
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
def arl_recommender(rules_df, id, rec=1):
    sorted_rules = rules_df.sort_values("lift", ascending=False)
    recommendation_list = []
    for i, k in enumerate(sorted_rules["antecedents"]):
        for j in list(k):
            if j == id :
                for k in list(sorted_rules.iloc[i]["consequents"]):
                    if k not in recommendation_list:
                        recommendation_list.append(k)

    return recommendation_list[0:rec]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
arl_recommender(rules,21137,5)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [27966, 47209, 13176, 21903, 8277]

# %%
#products = pd.read_csv("D:/DiscountMate/instacart_data/products.csv")
products = pd.read_csv("/content/products.csv")
products.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# 4             13

# %%
def names_of_products(rules_df, bought,recommend = 5):

    rec = arl_recommender(rules_df,bought,recommend)

    name_of_rec={}
    bought_name = products[products["product_id"]==bought]["product_name"].iloc[0]
    for i in rec:
        name_of_rec[i] = products[products["product_id"]==i]["product_name"].iloc[0]
    recommend_df = pd.DataFrame(name_of_rec.items(), columns=["product_id","product_name"])
    print(f"Bought: {bought_name}\n")
    return recommend_df
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
names_of_products(rules,21137,5)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Bought: Organic Strawberries
#    product_id              product_name
# 0       27966       Organic Raspberries
# 1       47209      Organic Hass Avocado
# 2       13176    Bag of Organic Bananas
# 3       21903      Organic Baby Spinach
# 4        8277  Apple Honeycrisp Organic

# %%
import joblib

# Save the model using joblib
joblib.dump(names_of_products, 'product_recommendation_model.joblib')

# Load the model using joblib
model = joblib.load('product_recommendation_model.joblib')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
