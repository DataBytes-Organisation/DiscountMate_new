# %% [markdown]
# # Sales Analyzer & Price Comparator

# %%
import pandas as pd

# Load the CSV files
woolies_df = pd.read_csv('customer_transactions_woolies.csv')
coles_df = pd.read_csv('customer_transactions_coles.csv')

# %% [markdown]
# ## Keyword-Based Sales Analyzer

# %%
def keyword_sales_summary(keyword, woolies_df, coles_df):
    
    # Combine both store data into one DataFrame and label the source store
    all_data = pd.concat([woolies_df.assign(Store="Woolworths"), coles_df.assign(Store="Coles")])
    
    # Filter the combined data for items that contain the keyword in their name (case-insensitive)
    filtered = all_data[all_data["ItemName"].str.contains(keyword, case=False, na=False)]
    
# Group the filtered data by item name and summarize:
    # - Total quantity sold
    # - Number of unique customers who bought it
    # - Number of different stores it appeared in
    summary = (
        filtered.groupby("ItemName")
        .agg(
            TotalSold=("Quantity", "sum"),
            UniqueCustomers=("CustomerID", pd.Series.nunique),
            StoreCount=("Store", "nunique")
        )
        .sort_values("TotalSold", ascending=False) # Sort items by how much was sold, descending
        .reset_index()
    )
    
    # If the summary is not empty, mark the top-selling item
    if not summary.empty:
        summary["Remark"] = ""  # Create a new column to annotate
        summary.loc[0, "Remark"] = "Most Sold"   # Flag the top item as the most sold
    
    # Save the result to a CSV file
    summary.to_csv("keyword_sales_summary.csv", index=False)
    return summary

# %%
# Prompt the user to enter a keyword to search products by name
keyword = input("Enter a keyword (Product name) to analyze product sales: ").strip()

# Call the function to analyze products that match the keyword and get the summary DataFrame
summary_df = keyword_sales_summary(keyword, woolies_df, coles_df)

# Display the keyword and corresponding summary
print(f"Results for keyword: '{keyword}'")
print(summary_df)

# Suggestion to compare partially matched products across stores
# Extract all item names that matched the keyword search
matching_products = summary_df["ItemName"].tolist()

# Print each matching product to guide the user for further comparison or selection
print("\nProducts matching the keyword across stores:")
for product in matching_products:
    print("-", product)
# Out:
# Results for keyword: 'chips'
#                                               ItemName  TotalSold  \
# 0              KB's Seafood Crumbed Squid Chips | 200g        375
# 1    Old El Paso Nachips Tortilla Chips Cheese Flav...        105
# 2                Orion Turtle Chips Choco Churros 160g         95
# 3                  Mission White Strip Corn Chips 500g         89
# 4              Calbee Potato Chips Pizza Flavoured 55g         84
# ..                                                 ...        ...
# 368           Coles Stone Ground Tortilla Chips | 400g          5
# 369        Noshu 95% Sugar Free Choc Baking Chips 140g          5
# 370  Vege Chips Deli Crisps Yellow Sweet Potato | 100g          5
# 371         Wicked Sweet Heat Pickle Chips Mild | 500g          5
# 372      Kettle Natural Potato Chips Fig & Brie | 150g          3
#
#      UniqueCustomers  StoreCount     Remark
# 0                158           1  Most Sold
# 1                 44           1
# 2                 39           1
# 3                 37           1
# 4                 35           1
# ..               ...         ...        ...
# 368                4           1
# 369                3           1
# 370                4           1
# 371                3           1
# 372                1           1
#
# [373 rows x 5 columns]
#
# Products matching the keyword across stores:
# - KB's Seafood Crumbed Squid Chips | 200g
# - Old El Paso Nachips Tortilla Chips Cheese Flavoured 350g
# - Orion Turtle Chips Choco Churros 160g
# - Mission White Strip Corn Chips 500g
# - Calbee Potato Chips Pizza Flavoured 55g
# - Indomie Chitato Mi Goreng Chips 55g
# - Orion Turtle Chips Corn Soup 160g
# - Old El Paso Tortilla Chips Original 350g
# - Coles Vegetable Chips | approx 100g
# - Orion Turtle Chips Sweet Vanilla 160g
# - Primo Trios Minions Ham Cheese & Banana Chips 47g
# - Sonora Supreme Cheese Corn Chips 500g
# - O'food Seaweed Chips Wasabi Chips Wasabi 35g
# - Calbee Potato Chips Hot & Spicy 55g
# - Mission Corn Chips Chilli & Lime 230g
# - Mccain Straight Sweet Potato Chips 750g
# - Old El Paso Nachips Tortilla Chips Original 350g
# - Mission Corn Chips Cheesy Nachos 230g
# - Sonora Corn Chips Salted 500g
# - Nong Shim Shrimp Meat Chip Shrimp Meat Chips 75g
# - Orion Turtle Chips Steak Wasabi 160g
# - Orion Turtle Chips Flaming Mala 160g
# - Crown Maple Corn Chips Canadian Maple 154g
# - O'food Seaweed Chips Original Chips Original 35g
# - Strong Roots Proper Chips 650g
# - Smith's Thinly Cut Potato Chips Sweet Chilli & Sour Cream 175g
# - Woolworths Shoestring Fries Chips 900g
# - Thins Sour Cream & Chives Potato Chips 175g
# - On The Menu Beer Battered Fish & Chips Frozen Meal 320g
# - Birds Eye Deli Seasoned Chips Parmesan, Garlic & Basil 600g
# - Smith's Crinkle Cut Potato Chips Cheese & Onion 60g
# - Mission Corn Chips Deli Round 500g
# - Simply Sea Salt & Cracked Pepper 25% Less Fat Potato Chips 120g
# - Red Rock Deli Potato Chips Honey Soy Chicken Deli Style 50g
# - Essentials Frozen Crinkle Cut Chips 1kg
# - Woolworths Supreme Cheese Corn Chips 175g
# - Birds Eye Deli Seasoned Chips Golden Ale Beer Batter 600g
# - Tostitos Tortilla Corn Chips Splash Of Lime Cantina Style 175g
# - The Natural Chip Co. Honey Soy Chicken Chips Honey Soy Chicken 6 Pack
# - Woolworths Steakhouse Chips 900g
# - McCain Quick Cook Crinkle Cut Chips | 750g
# - Bell Farms Crunchy Chips Frozen 1kg
# - Red Rock Deli Potato Chips Lime & Black Pepper 165g
# - Woolworths Crispy Crinkle Cut Chips 900g
# - The Natural Chip Co. Lightly Salted Chips 6 Pack
# - Mccain Beer Batter Chips Shoestring 750g
# - Kettle Classic Sea Salt Chips Potato Chips 165g
# - Smith's Thinly Cut Potato Chips Original Share Pack 175g
# - Woolworths Crinkle Cut Chips 900g
# - Arnott's Cracker Chips Honey Soy Chicken 150g
# - Thins Multipack Classic Original Chips 6 Pack
# - Pringles Bbq Stacked Potato Chips 134g
# - Birds Eye Golden Crunch Thin & Crispy Chips 900g
# - Mccain Beer Batter Steakhouse Chips 750g
# - Woolworths Australian Beer Batter Steakhouse Chips 750g
# - Smith's Oven Baked Salt & Vinegar Chips 130g
# - Smith's Potato Chips Original Favourites Multipack Variety 20 Pack
# - Pringles Sour Cream & Onion Potato Chips 134g
# - Birds Eye Golden Crunch Crinkle Cut Chips 900g
# - Birds Eye Golden Crunch Straight Cut Chips 900g
# - Red Rock Deli Potato Chips Sweet Chilli & Sour Cream 165g
# - Red Rock Deli Potato Chips Multipack Honey Soy Chicken 5 Pack
# - Pringles Minis Multipack Original Potato Chips 5 Pack
# - Cc's Corn Chips Nacho Cheese 175g
# - McCain Beer Battered Potato Chips Frozen Chunky | 750g
# - Pringles Sour Cream & Onion Potato Chips 53g
# - Smith's Crinkle Cut Potato Chips Original 60g
# - Kettle Crafted Collection Angus Beef & Caramelised Onion Chips 150g
# - Mccain Gluten Free Potato Chips 750g
# - Cc's Corn Chips Original 175g
# - Woolworths Crinkle Cut Chips Roast Chicken 175g
# - Jumpy's Chicken Chips 5 Pack
# - Smith's Crinkle Cut Cheese & Onion Potato Chips Multipack 114g
# - Pringles Chipotle Sour Cream Flavour Stacked Potato Chips 118g
# - The Real Mccoy Thin Cut Chips Sea Salt & Vinegar Value Pack 220g
# - The Natural Chip Company Cheese & Onion Chips 175g
# - Woolworths Crispy Straight Cut Chips 900g
# - Woolworths Honey Soy Chicken Deli Style Chips 175g
# - Kb's Tender Squid Chips Lightly Crumbed | 1kg
# - Sunbites Grainwaves Sour Cream & Chives Wholegrain Chips Multipack 110g
# - Smith's Thinly Cut Potato Chips Sour Cream & Onion Share Pack 175g
# - Cc's Cornados Corn Chips Sour Cream & Chives 110g
# - Smith's Crinkle Cut Potato Chips Salt & Vinegar 170g
# - Pringles South American Bbq Flavour Stacked Potato Chips 118g
# - Birds Eye Microwave Chips Crinkle 140g
# - Mccain Pub Style Extra Crispy Chips 750g
# - Smith's Oven Baked Chips Sea Salt 130g
# - Bell Farms Frozen Chips Steak Cut 1kg
# - Birds Eye Deli Seasoned Chips Sea Salt & Rosemary 600g
# - Doritos Corn Chips Fire & Fury Pizza | 150g
# - Pringles Potato Chips South American Grill | 118g
# - Doritos Corn Chips Cheese Supreme Flaming Hot | 150g
# - Doritos Corn Chips Cheese Supreme 5 Pack
# - Simply Potato Chips Tangy Herb & Spice 120g
# - Smith's Crinkle Cut Potato Chips Chicken 60g
# - Smith's Crinkle Cut Potato Chips Barbecue 170g
# - Birds Eye Deli Sweet Potato Chips 600g
# - Doritos Corn Chips Cheese Supreme Party Size 380g
# - Birds Eye Golden Crunch Lattice Potato Chips Criss Cross French Fries 750g
# - Samboy Samboy Barbecue Crinkle Cut Potato Chips 90g
# - Smith's Oven Baked Chips Sour Cream & Chives 130g
# - Doritos Corn Chips Nacho Cheese Share Pack 170g
# - Belvita Breakfast Biscuits Honey & Nut With Chocolate Chips 6 Pack
# - Coles Frozen Crinkle Cut Chips | 1kg
# - Smith's Double Crunch Cheesy Garlic Bread Potato Chips Share Pack 150g
# - Quest Tortilla Style Protein Chips Nacho Chips | 32g
# - Smith's Crinkle Original Potato Chips | 380g
# - Kettle Honey Soy Chicken Chips Potato Chips 165g
# - Kettle Crafted Collection Black Truffle & Sea Salt Chips 150g
# - Cc's Corn Chips Tangy Salsa 175g
# - Woolworths Banana Chips 300g
# - Thins Cheese & Onion Chips 175g
# - Coles Frozen Sweet Potato Chips | 750g
# - Gravox Best Ever Hot Chip Gravy Pouch Liquid Gravy For Chips 165g
# - Red Rock Deli Potato Chips Multipack Sweet Chilli & Sour Cream 5 Pack
# - Woolworths Crinkle Cut Chips Original Crinkle Cut Original 175g
# - McCain Beer Batter Potato Chips Frozen Steak Cut | 750g
# - Real Mexican Feast Tasty Cheese Corn Chips Guacam ... 85g
# - Thins Potato Chips Cheddar Cheese | 150g
# - Thins Chips Limited Edition Sausage Sizzle 150g
# - Smith's Crinkle Chilli Potato Chips | 170g
# - On The Menu Chicken Parmigiana With Cheesy Chips & Veg 480g
# - Red Rock Deli Trio Of Cheeses Potato Chips Share Pack 150g
# - Pringles Minis Multipack Salt & Vinegar Potato Chips 5 Pack
# - Jumpy's Variety Multi Pack Chips 10 Pack
# - French Fries Original Chips 175g
# - Essentials Frozen Straight Cut Potato Chips 1kg
# - Birds Eye Deli Golden Ale Chips | 600g
# - Reeses Peanut Butter Baking Chips | 283g
# - Tyrrell's Crinkly Chips Lightly Sea Salted 165g
# - Keep It Cleaner Lentil Chips Sea Salt | 90g
# - Birds Eye Microwave Chips Shoestring 140g
# - Smith's Crinkle Cut Chips Salt & Vinegar 60g
# - Doritos Corn Chips Original Share Pack 170g
# - Keep It Cleaner Lentil Chips Sea Salt & Roast Garlic | 90g
# - Smith's Double Crunch Original Potato Chips Share Pack 150g
# - Smith's Double Crunch Ultimate Bbq Ribs Potato Chips Share Pack 150g
# - Smiths Grainwaves Chips Sour Cream Chives | 40g
# - Thins Chips Salt & Vinegar 175g
# - Doritos Corn Chips Cheese Supreme Share Pack 170g
# - Pringles Original Salted Potato Chips 134g
# - Red Rock Deli Potato Chips Dijon Mustard & Honey 165g
# - Kettle Vintage Cheddar With Cracked Peppercorns Chips 150g
# - Cc's Cornados Corn Chips Cheese Supreme 110g
# - Vege Chips Multi 12 Pack 250g
# - Smith's Crinkle Cut Potato Chips Original 170g
# - Thins Chips Original 175g
# - Woolworths Chips Variety Pack 20 Pack 380g
# - Tyrrell's Crinkly Chips Mature Cheddar & Chives 165g
# - McCain Superfries Frozen Potato Chips Crinkle Cut | 900g
# - Red Rock Deli Potato Chips Thai Chilli & Lime | 165g
# - Doritos Corn Chips Cheese Supreme Flaming Hot 150g
# - Red Rock Deli Potato Chips Honey Soy Chicken Entertaining Size 290g
# - Coles Bake & Create White Chocolate Chips | 200g
# - Smiths Crinkle Cut Potato Chips Farmhouse C ... 150g
# - Pringles Minis Multipack Sour Cream & Onion Potato Chips 5 Pack
# - Family Fave's Chicken Chips With Ciabatta Crumb | 1kg
# - Pringles Cheese Potato Chips | 134g
# - Red Rock Deli Potato Chips Honey Soy Chicken 165g
# - Pringles Cheese Stacked Potato Chips 134g
# - Sunrice Brown Rice Chips Cheese | 150g
# - Kettle Sweet Potato Chips Sea Salt 135g
# - Cadbury Baking White Chocolate Chips 200g
# - Coles Beer Battered Steakhouse Chips | 750g
# - Sunbites Grain Waves Wholegrain Chips Sweet Chilli 170g
# - Birds Eye Golden Crunch Sidewinders Twisty Potato Chips 750g
# - Pringles Salt & Vinegar Flavour Potato Chips 134g
# - Pringles Potato Chips Korean Style BBQ | 118g
# - Kettle Sea Salt & Vinegar Chips Chips 165g
# - McCain Superfries Frozen Potato Chips Shoestring | 900g
# - Arnott's Cracker Chips Honey Soy Chicken | 150g
# - Woolworths Steakhouse Chips 1kg
# - Doritos Corn Chips Supreme Cheese Share Pack | 170g
# - Red Rock Deli Potato Chips Sea Salt & Balsamic Vinegar 165g
# - Red Rock Deli Potato Chips Sea Salt Natural 165g
# - Green's Chocolate Chunk Cookies With Dark Chocolate Chips 400g
# - Red Rock Deli Potato Chips Smoked Chipotle & Honey 150g
# - CC's Original Corn Chips | 175g
# - Smith's Crinkle Cut Potato Chips Chicken 170g
# - Smith's Crinkle Cut Potato Chips Multipack Original 6 Pack
# - Woolworths Sea Salt Deli Style Potato Chips 175g
# - Smith's Original Thinly Cut Potato Chips | 175g
# - Kettle Crafted Collection Applewood Smoked Butter & Salt Chips 150g
# - Smith's Crinkle BBQ Potato Chips | 170g
# - Simply Regular Corn Chips Zesty Lime Chilli | 130g
# - On The Menu Frozen Beer Battered Fish & Chips | 320g
# - Smiths Crinkle Potato Chips Roast Beef Garlic | 150g
# - Red Rock Deli Poato Chips Sweet Chilli Multipack 5 P ... 140g
# - Smith's Crinkle Cut Chips Salt & Vinegar Party Size 380g
# - Red Rock Deli Potato Chips Multipack Variety - Deli Style 28g X10 Pack
# - McCain Superfries Frozen Potato Chips Straight Cut | 900g
# - Red Rock Deli Potato Chips Sweet Chilli And Sour Cre ... 165g
# - Thins Potato Chips Outback BBQ | 150g
# - Woolworths Original Flavour Stacked Chips 160g
# - Doritos Corn Chips Cheese Supreme 60g
# - Coles Corn Chips Original | 175g
# - Smith's Potato Chips Snack Mix Multipack Variety 20 Pack
# - Vege Chips Natural | 100g
# - Vege Chips Rice Crackers Sour Cream & Chives | 75g
# - Coles Finest Goats Cheese Polenta Chips | 200g
# - Red Rock Deli Honey Soy Chicken Potato Chips | 165g
# - Birds Eye Golden Crunch Straight Cut Chips | 900g
# - Woolworths Original Salted Corn Chips 175g
# - Bell Farms Sweet Potato Chips 750g
# - Doritos Street Art Corn Chips The Boss Taco | 150g
# - Pringles Minis Multipack Chicken Flavour Potato Chips 5 Pack
# - Red Rock Deli Potato Chips Sweet Chilli & Sour Cream | 50g
# - Pana Organic Chocolate Chips Dark | 135g
# - Smith's Crinkle Cut Chicken Potato Chips | 170g
# - Sunbites Grain Waves Chips Sweet Chilli | 170g
# - Red Rock Deli Potato Chips Honey Soy Chicken Multi ... 140g
# - Coles Potato Chips Crinkle Cut Original 20 pack | 380g
# - Samba Smoking Chips 300g
# - Orion Turtle Chips Truffle Flavour | 80g
# - Vege Chips BBQ | 100g
# - Calbee Hot & Spicy Potato Chips | 55g
# - Thins Top 20 Variety Multipack Chips 20 Pack 375g
# - Kettle Chilli Potato Chips | 165 gram
# - Kettle Chilli Potato Chips  | 70g
# - Thins Salt & Vinegar Potato Chips | 175g
# - Natural Chip Co. Honey Soy Chicken Potato Chips | 175g
# - Smith's Crinkle Cut Potato Chips Multipack Salt, Vinegar 6 Pack
# - Red Rock Deli Sea Salt Potato Chips | 50g
# - Top 20 Variety Potato Chips 20 pack | 375g
# - Kettle Sweet Potato Chips Sea Salt | 135g
# - Smith's Thinly Cut Chips 40% Less Sodium Lightly Tangy 175g
# - Smiths Crinkle Potato Chips Chicken | 60g
# - Cc's Corn Chips Tasty Cheese 175g
# - Sunbites Grain Waves Wholegrain Chips Sour Cream & Chives 170g
# - Kozhikoden's Banana Chips | 200g
# - Thins Chips Light & Tangy 175g
# - Doritos Corn Chips Nacho Cheese Sh ... 170g
# - Thins Sour Cream & Chives Potato Chips | 175g
# - Cadbury Caramilk Baking Chips | 260g
# - Kettle Sea Salt & Vinegar Potato Chips | 165g
# - Thins Chips Chicken 175g
# - Natural Chip Co Aussie BBQ Chips | 175g
# - Doritos Original Corn Chips | 380g
# - Kettle Sweet Chilli & Sour Cream Potato Chips 165g
# - Thins Chips Chilli 150g
# - Smiths Salt & Vinegar Crinkle Potato Chips | 60g
# - Kettle Honey Soy Chicken Potato Chips | 165g
# - French Fries Original Potato Chips | 175g
# - Vege Chips Rice Crackers Sweet Chilli & Sour Cream | 75g
# - Smith's Crinkle Cut Original Chips 6 pack | 114g
# - Smith's Crinkle Cut Salt And Vinegar Potato Chips | 380g
# - Sunbites Grain Waves Chips Sea Salt | 170g
# - Tostitos Tortilla Corn Chips Lightly Salted Cantina Style 175g
# - Kettle Sea Salt Potato Chips  | 70g
# - Keep It Cleaner Lentil Chips Vegan Cheese & Jalapeno | 90g
# - Coles Potato Chips Crinkle Cut Original | 175g
# - Orion Turtle Chips Choco Churros | 80g
# - Kettle Potato Chips Chilli 165g
# - Indomie Chitato MI Goreng Potato Chips | 55g
# - Smith's Crinkle Cut Salt And Vinegar Potato Chips | 170g
# - Cadbury White Chocolate Baking Chips | 200g
# - Smith's Thinly Cut Chips Lightly Salted 6 Pack | 114g
# - Kettle Original Sea Salt Potato Chips 5 pack | 92g
# - Nongshim Shrimp Meat Chips | 75g
# - Doritos Corn Chips Mexicana Share Pack 170g
# - On The Menu Chicken Parma With Cheesy Chips & Veg | 480g
# - Smith's Crinkle Cut Cheese & Onion Potato Chips | 170g
# - Doritos Thai Sweet Chilli Corn Chips | 150g
# - Cadbury Baking Milk Chocolate Chips Value Pack 410g
# - Sunrice Protein Chips Sour Cream & Chives | 50g
# - Vege Chips Multi 12 Pack | 250g
# - Pringles Original Salted Stacked Potato Chips | 134g
# - Sunbites Grain Waves Chips Cheddar | 170g
# - Pringles Potato Chips Sizzlin Cajun Spice | 118g
# - Tostitos Lightly Salted Tortilla Chips | 175g
# - Pringles Potato Chips Chipotle & Sour Cream | 118g
# - Pringles Original Salted Potato Chips 53g
# - Sunrice Brown Rice Chips Smoky BBQ Tomato & Herb | 150g
# - Doritos Original Corn Chips Salted | 170g
# - Smith's Crinkle Cut Original Potato Chips | 170g
# - Coles Bake & Create Milk Chocolate Chips | 200g
# - Birds Eye Golden Crunch Crinkle Cut Chips | 900g
# - Vege Chips Natural Multipack 12 Pack | 250g
# - Noshu 95% Sugar Free Chocolate Baking Chips | 140g
# - Smith's Thinly Cut Potato Chips Share Pack Salt & Vinegar 175g
# - Pringles Minis Sour Cream & Onion Potato Chips 5 ... 95g
# - Red Rock Deli Potato Chips Honey Mustard | 165g
# - DJ&A Sweet Potato Mix Chips | 70g
# - Smith's Salt And Vinegar Thinly Cut Potato Chips | 175g
# - Smith's Potato Chips Fun Mix Multipack Variety 20 Pack
# - Smith's Crinkle Cut Potato Chips Cheese & Onion 170g
# - Orion Turtle Chips Corn Soup Flavour | 80g
# - Reese's Peanut Butter Chips 283g
# - Coles Frozen Straight Cut Chips | 1kg
# - Simply Sour Cream & Chives 25% Less Fat Potato Chips Share Pack 120g
# - Vege Chips Sea Salt & Vinegar | 100g
# - Jumpy's Potato Chips 10 Pack | 180g
# - Natural Chip Co. Sea Salt Potato Chips | 175g
# - Cadbury Cadbury Caramilk Chocolate Baking Chips 260g
# - Doritos Corn Chips Chaos Cajun Chicken | 150g
# - Vege Chips Deli Crisps Lentil Lightly Salted | 100g
# - CC's Tasty Cheese Corn Chips | 175g
# - Coles Crinkle Cut Chicken Potato Chips | 175g
# - Blue Bird Original Green Onion Cut Chips | 150g
# - Pringles Potato Chips Salt & Vinegar | 53g
# - The Real Mccoy Crinkle Cut Chips Sea Salt Value Pack 220g
# - Red Rock Deli Chef Series Crispy Chicken With Garlic & Sweet Soy Chips 150g
# - Mission Chilli & Lime Tortilla Triangles Corn Chips | 230g
# - Noshu 97% Sugar Free Dark Choc Baking Chips 140g
# - French Fries Original Potato Chips 6 pack | 111g
# - Thins Chicken Potato Chips | 175g
# - Doritos Corn Chips Mexicana Share Pack | 170g
# - Coles Deli Style Potato Chips Sea Salt | 175g
# - Smiths Original Crinkle Potato Chips | 60g
# - Red Rock Deli Potato Chips Sea Salt | 165g
# - Samboy BBQ Potato Chips | 90g
# - Smith's Crinkle Cut Chips Party Size Original 380g
# - Cadbury Milk Chocolate Baking Chips | 200g
# - Smith's Sour Cream And Onion Thinly Cut Potato Chips | 175g
# - CC's Nacho Cheese Corn Chips | 175g
# - Cadbury Baking Milk Chocolate Chips 200g
# - Kettle Sea Salt Potato Chips | 165g
# - Doritos Supreme Cheese Corn Chips | 60g
# - Coles Crinkle Cut Salt & Vinegar Potato Chips | 175g
# - Smith's Thinly Cut Lightly Salted Less Salt Potato Chips Multipack 114g
# - Quest Tortilla Style Protein Chips Loaded Taco | 32g
# - Noshu 97% Sugar Free Dark Chocolate Baking Chips | 140g
# - Coles Banana Chips | 200g
# - Woolworths Sour Cream & Onion Stacked Chips 160g
# - Sunbites Grain Waves Chips Sour Cream & Chives | 170g
# - Smiths Tasty Mix Variety Multipack Pot Chips 20 Pack | 368g
# - Smiths Potato Chips Crinkle Flavour Mix Variety 20 Pack | 380g
# - Natural Chip Co. Sea Salt & Vinegar Potato Chips | 175g
# - Thins Original Potato Chips | 175g
# - Doritos Corn Chips Cheese Supreme Multipack 9 ... 5 pack
# - Pringles Original Salted Stacked Potato Chips | 53g
# - Red Rock Deli Sweet Chilli & Sour Cream Potato Chips | 290g
# - Coles Dark Compound Choc Chips | 250g
# - Pana Organic Chocolate Chips Mylk | 135g
# - Doritos Cheese Supreme Corn Chips Sharepack | 380g
# - Coles Muesli Bars Choc Chips 8 Pack | 248g
# - Red Rock Deli Honey Soy Chicken Potato Chips | 50g
# - Pringles Sour Cream & Onion Stacked Potato Chips | 53g
# - Quest Tortilla Style Protein Chips Ranch | 32g
# - Tostitos Splash Of Lime Tortilla Chips | 175g
# - Coles Deli Style Potato Chips Honey Soy Chick | 175g
# - Smith's Double Crunch Original Potato Chips | 150g
# - Noshu Sugar Free White Choc Baking Chips 140g
# - Smith's Crinkle Cut Salt & Vinegar Potato Chips 6 pack | 114g
# - Bryne Co Sweet Heat Pickle Chips Mild 500g
# - CC's Corn Chips Chilli & Lime | 175g
# - Vege Chips Mini Rice Crackers Multi 12 Pack | 180g
# - Cadbury Baking Dark Chocolate Chips 200g
# - Thins Light & Tangy Potato Chips | 175g
# - Sunrice Brown Rice Chips Sea Salt | 150g
# - Noshu 95% Sugar Free White Chocolate Baking Chips | 140g
# - Vege Chips Deli Crisps Purple Sweet Potato | 100g
# - Arnott's Cracker Chips Balsamic Vinegar & Sea ... 150g
# - Calbee Pizza Potato Chips | 55g
# - Coles Corn Chips Cheese Supreme | 175g
# - Red Rock Deli Lime & Pepper Potato Chips | 165g
# - Cadbury Milk Chocolate Baking Chips Value P ... 410g
# - Coles Deli Multipack Assorted Chips 15 Pack | 278g
# - Red Rock Deli Potato Chips Chipotle & Honey | 150g
# - Otep Brown Rice Chips With Pumpkin Caramelised O ... 75g
# - Tyrells Potato Chips Crinkle Cut Top Notch BBQ | 165g
# - Sunrice Protein Chips Barbeque | 50g
# - Smith's Cheese Twisties Chips 6 pack | 114g
# - Pringles Sour Cream & Onion Potato Chips | 134g
# - Kettle Potato Chips Sea Salt | 300g
# - Cadbury Dark Chocolate Baking Chips | 200g
# - Red Rock Deli Sea Salt & Bal Vinegar Potato Chips | 165g
# - Pringles BBQ Stacked Potato Chips | 134g
# - Coles Stone Ground Tortilla Chips | 400g
# - Noshu 95% Sugar Free Choc Baking Chips 140g
# - Vege Chips Deli Crisps Yellow Sweet Potato | 100g
# - Wicked Sweet Heat Pickle Chips Mild | 500g
# - Kettle Natural Potato Chips Fig & Brie | 150g

# %% [markdown]
# ## Price Comparison for a Specific Product

# %%
def compare_prices(product_name, woolies_df, coles_df):
    # Normalize column names to avoid KeyErrors due to hidden whitespace or casing
    woolies_df.columns = woolies_df.columns.str.strip()
    coles_df.columns = coles_df.columns.str.strip()

    # Add Store column and combine both DataFrames
    woolies = woolies_df.assign(Store="Woolworths")
    coles = coles_df.assign(Store="Coles")
    combined = pd.concat([woolies, coles])

    # Check for 'ItemName' column
    if 'ItemName' not in combined.columns or 'UnitPrice' not in combined.columns:
        print("Required columns 'ItemName' or 'UnitPrice' are missing.")
        print(f"Available columns: {combined.columns.tolist()}")
        return

    # Perform case-insensitive partial matching
    matches = combined[combined["ItemName"].str.contains(product_name, case=False, na=False)]
    
    # Handle the case where no products matched the input keyword
    if matches.empty:
        print("No matching products found.")
        return

    print(f" Found {len(matches)} matching entries. Grouping by product and store...")

    # Group and sort by price
    grouped = (
        matches.groupby(["ItemName", "Store"])["UnitPrice"]
        .min()            # Get the minimum price per product/store combo
        .reset_index()    # Flatten the groupby object into a DataFrame
        .sort_values("UnitPrice")       # Sort from cheapest to most expensive
    )

    # Print cheapest option
    cheapest = grouped.iloc[0]   # Get the top row — the cheapest entry after sorting
    
    # Display the best match details clearly
    print(f"\n Cheapest match is:\n'{cheapest['ItemName']}' at {cheapest['Store']} for ${cheapest['UnitPrice']:.2f}")
    
    # Also display all the grouped results so the user can compare other options
    print("\n All matches:")
    print(grouped)

# %%
#Prompt the user to enter part of the product name for flexible price comparison
product_name = input("Enter the exact product name for price comparison: ").strip()
compare_prices(product_name, woolies_df, coles_df) #Run the price comparison using the updated compare_prices function
# Out:
#  Found 4825 matching entries. Grouping by product and store...
#
#  Cheapest match is:
# 'Nong Shim Shrimp Meat Chip Shrimp Meat Chips 75g' at Woolworths for $1.45
#
#  All matches:
#                                               ItemName       Store  UnitPrice
# 150   Nong Shim Shrimp Meat Chip Shrimp Meat Chips 75g  Woolworths       1.45
# 293    Smiths Grainwaves Chips Sour Cream Chives | 40g       Coles       1.50
# 49                           Coles Banana Chips | 200g       Coles       2.00
# 175  Otep Brown Rice Chips With Pumpkin Caramelised...       Coles       2.00
# 190          Pringles Original Salted Potato Chips 53g  Woolworths       2.00
# ..                                                 ...         ...        ...
# 350        Vege Chips Natural Multipack 12 Pack | 250g       Coles       9.50
# 348                      Vege Chips Multi 12 Pack 250g  Woolworths       9.50
# 349                    Vege Chips Multi 12 Pack | 250g       Coles       9.50
# 93   Family Fave's Chicken Chips With Ciabatta Crum...       Coles      13.00
# 105      Kb's Tender Squid Chips Lightly Crumbed | 1kg       Coles      27.50
#
# [373 rows x 3 columns]
