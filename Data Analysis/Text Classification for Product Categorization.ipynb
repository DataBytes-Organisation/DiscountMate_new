# %% [markdown]
# # Text Classification for Product Categorization

# %% [markdown]
# ## Importing Packages

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF

# %%
Grocery = pd.read_csv('GroceryDataset.csv')
Grocery.head()
# Out:
#         Sub Category     Price     Discount
# 0  Bakery & Desserts   $56.99   No Discount  \
# 1  Bakery & Desserts  $159.99   No Discount
# 2  Bakery & Desserts   $44.99   No Discount
# 3  Bakery & Desserts   $39.99   No Discount
# 4  Bakery & Desserts   $59.99   No Discount
#
#                                             Rating
# 0   Rated 4.3 out of 5 stars based on 265 reviews.  \
# 1       Rated 5 out of 5 stars based on 1 reviews.
# 2   Rated 4.1 out of 5 stars based on 441 reviews.
# 3  Rated 4.7 out of 5 stars based on 9459 reviews.
# 4   Rated 4.5 out of 5 stars based on 758 reviews.
#
#                                                Title Currency
# 0  David’s Cookies Mile High Peanut Butter Cake, ...        $  \
# 1  The Cake Bake Shop 8" Round Carrot Cake (16-22...        $
# 2  St Michel Madeleine, Classic French Sponge Cak...        $
# 3  David's Cookies Butter Pecan Meltaways 32 oz, ...        $
# 4  David’s Cookies Premier Chocolate Cake, 7.2 lb...        $
#
#                                              Feature
# 0  "10"" Peanut Butter Cake\nCertified Kosher OU-...  \
# 1  Spiced Carrot Cake with Cream Cheese Frosting ...
# 2  100 count\nIndividually wrapped\nMade in and I...
# 3  Butter Pecan Meltaways\n32 oz 2-Pack\nNo Prese...
# 4  "10" Four Layer Chocolate Cake\nCertified Kosh...
#
#                                  Product Description
# 0  A cake the dessert epicure will die for!Our To...
# 1  Due to the perishable nature of this item, ord...
# 2  Moist and buttery sponge cakes with the tradit...
# 3  These delectable butter pecan meltaways are th...
# 4  A cake the dessert epicure will die for!To the...

# %% [markdown]
# ## Cleaning data

# %%
nan_index = Grocery[Grocery['Product Description'].isnull()].index

# %%
Grocery.drop(nan_index, inplace=True)

# %%
Grocery['Sub Category'].nunique()
# Out:
# 19

# %% [markdown]
# # Applying TFIDF

# %%
tfidf = TfidfVectorizer(max_df=0.95, min_df=2, stop_words='english')

# %%
dtm = tfidf.fit_transform(Grocery['Product Description'])

# %% [markdown]
# # Non-negative Matrix Factorization

# %%
nmf_model = NMF(n_components=19,random_state=42)

# %%
nmf_model.fit(dtm)
# Out:
# NMF(n_components=19, random_state=42)

# %%
for index, topic in enumerate(nmf_model.components_):
    print(f'THE TOP 15 WORDS FOR TOPIC #{index}')
    print([tfidf.get_feature_names_out()[i] for i in topic.argsort()[-15:]])
    print('\n')
# Out:
# THE TOP 15 WORDS FOR TOPIC #0
# ['days', 'contact', 'help', 'need', 'ship', 'friday', 'event', 'calendar', 'checkout', 'arrival', 'date', 'order', 'arrive', 'orders', 'flowers']
#
#
# THE TOP 15 WORDS FOR TOPIC #1
# ['chips', '64', '32', 'qty', 'count2', '40', 'mints', '75', '42', 'bags', 'cheese', '15', '12', 'count1', 'oz']
#
#
# THE TOP 15 WORDS FOR TOPIC #2
# ['tender', 'company', 'black', 'lobster', 'fed', 'chicken', 'meat', 'aged', 'raised', 'angus', 'filet', 'burgers', 'steaks', 'beef', 'steak']
#
#
# THE TOP 15 WORDS FOR TOPIC #3
# ['certifieddark', 'counttotal', 'arabica', 'beankosher', 'chocolatetotal', 'bag2', 'packtotal', 'lb', 'coffeewhole', '32', '10', 'total', 'lbs', 'weight', 'net']
#
#
# THE TOP 15 WORDS FOR TOPIC #4
# ['chip', 'cake', 'butter', 'covered', 'size', 'caramel', 'bar', 'belgian', 'cookies', 'peanut', 'bars', 'dark', 'candy', 'milk', 'chocolate']
#
#
# THE TOP 15 WORDS FOR TOPIC #5
# ['certified', 'roasted', 'beans', 'medium', 'dark', 'dispose', 'starbucks', 'blend', '100', 'arabica', 'organic', 'keurig', 'roast', 'cup', 'coffee']
#
#
# THE TOP 15 WORDS FOR TOPIC #6
# ['resource', 'malossol', 'size', 'sustainable', 'medium', 'product', 'friendly', 'non', 'features', 'eco', 'plaza', 'farmed', 'osetra', 'sturgeon', 'caviar']
#
#
# THE TOP 15 WORDS FOR TOPIC #7
# ['dispose', 'cup', 'stick', 'limit', 'keurig', 'hew', 'model', 'item', 'non', 'available', 'local', 'delivered', 'lower', 'price', 'warehouse']
#
#
# THE TOP 15 WORDS FOR TOPIC #8
# ['00', 'plates', 'grown', 'anjou', 'basket', 'produced', 'california', '12', 'apples', '27', 'pears', 'baked', 'cans', 'packed', 'usa']
#
#
# THE TOP 15 WORDS FOR TOPIC #9
# ['lbs', 'king', 'lobster', 'northwest', 'caught', 'waters', 'alaskan', 'alaska', 'fish', 'seafood', 'smoked', 'frozen', 'wild', 'sockeye', 'salmon']
#
#
# THE TOP 15 WORDS FOR TOPIC #10
# ['contents', 'microwave', 'halves2', 'peanuts', 'freshness5', 'pecan', 'smoked10', 'opening', 'optimum', 'cashews', 'almonds', 'bags', 'resealable', 'bag', 'lb']
#
#
# THE TOP 15 WORDS FOR TOPIC #11
# ['100', 'load', 'nellie', 'power', 'cold', 'formula', 'water', 'wash', 'sheets', 'sodium', 'safe', 'loads', 'use', 'free', 'laundry']
#
#
# THE TOP 15 WORDS FOR TOPIC #12
# ['cup', '17', '18', '25', 'beef', 'pack15', '24', 'bag3', '12', 'pieces', '15', 'oz', '14', 'cans', 'count']
#
#
# THE TOP 15 WORDS FOR TOPIC #13
# ['kosher', 'vegan', 'keto', 'calories', 'protein', 'organic', 'natural', 'gmo', 'zero', 'energy', 'flavors', 'gluten', 'artificial', 'sugar', 'free']
#
#
# THE TOP 15 WORDS FOR TOPIC #14
# ['berry', 'sour', 'raspberry', 'cherry', 'candy', 'orange', '10', 'punch', 'strawberry', 'grape', 'pack', 'variety', 'juice', 'fruit', 'apple']
#
#
# THE TOP 15 WORDS FOR TOPIC #15
# ['energy', 'free1', '96', 'juice', '93', 'carton', 'total', '24', 'cans', 'volume', '32', 'bottle', 'ml', 'oz', 'fl']
#
#
# THE TOP 15 WORDS FOR TOPIC #16
# ['fermentation', 'acids', 'proteinate', 'food', 'sulfate', 'omega', 'lactobacillus', 'dog', 'minimum', 'supplement', 'fatty', 'kg', 'chicken', 'dried', 'vitamin']
#
#
# THE TOP 15 WORDS FOR TOPIC #17
# ['ribs', '50', 'packaged', 'pepper', 'hot', '20', 'chili', 'chips', 'tortilla', 'takis', 'theusa', 'store', 'place', 'dry', 'cool']
#
#
# THE TOP 15 WORDS FOR TOPIC #18
# ['prefecture', 'cut', 'flavor', 'mouth', 'raising', 'experience', 'imported', 'cattle', 'authentic', 'kagoshima', 'japanese', 'japan', 'beef', 'a5', 'wagyu']

# %% [markdown]
# # Add the topic Column

# %%
topic_results = nmf_model.transform(dtm)

# %%
topic_results.argmax(axis=1)

Grocery['Topic'] = topic_results.argmax(axis=1)

Grocery.head(10)
# Out:
#         Sub Category     Price     Discount
# 0  Bakery & Desserts   $56.99   No Discount  \
# 1  Bakery & Desserts  $159.99   No Discount
# 2  Bakery & Desserts   $44.99   No Discount
# 3  Bakery & Desserts   $39.99   No Discount
# 4  Bakery & Desserts   $59.99   No Discount
# 5  Bakery & Desserts   $59.99   No Discount
# 6  Bakery & Desserts   $74.99   No Discount
# 7  Bakery & Desserts   $59.99   No Discount
# 8  Bakery & Desserts   $29.99   No Discount
# 9  Bakery & Desserts  $159.99   No Discount
#
#                                             Rating
# 0   Rated 4.3 out of 5 stars based on 265 reviews.  \
# 1       Rated 5 out of 5 stars based on 1 reviews.
# 2   Rated 4.1 out of 5 stars based on 441 reviews.
# 3  Rated 4.7 out of 5 stars based on 9459 reviews.
# 4   Rated 4.5 out of 5 stars based on 758 reviews.
# 5   Rated 4.4 out of 5 stars based on 369 reviews.
# 6  Rated 4.7 out of 5 stars based on 2241 reviews.
# 7   Rated 4.4 out of 5 stars based on 232 reviews.
# 8  Rated 4.4 out of 5 stars based on 1679 reviews.
# 9       Rated 5 out of 5 stars based on 2 reviews.
#
#                                                Title Currency
# 0  David’s Cookies Mile High Peanut Butter Cake, ...        $  \
# 1  The Cake Bake Shop 8" Round Carrot Cake (16-22...        $
# 2  St Michel Madeleine, Classic French Sponge Cak...        $
# 3  David's Cookies Butter Pecan Meltaways 32 oz, ...        $
# 4  David’s Cookies Premier Chocolate Cake, 7.2 lb...        $
# 5  David's Cookies Mango & Strawberry Cheesecake ...        $
# 6  La Grande Galette French Butter Cookies, 1.3 l...        $
# 7  David's Cookies No Sugar Added Cheesecake & Ma...        $
# 8      David's Cookies Brownie and Cookie Combo Pack        $
# 9  The Cake Bake Shop 8" Round Chocolate Cake (16...        $
#
#                                              Feature
# 0  "10"" Peanut Butter Cake\nCertified Kosher OU-...  \
# 1  Spiced Carrot Cake with Cream Cheese Frosting ...
# 2  100 count\nIndividually wrapped\nMade in and I...
# 3  Butter Pecan Meltaways\n32 oz 2-Pack\nNo Prese...
# 4  "10" Four Layer Chocolate Cake\nCertified Kosh...
# 5  2-count\nStrawberry Cheesecake\nMango Cheeseca...
# 6  1.3 lb, 6-count\nBaked in, and Imported from, ...
# 7           2-count\nNo Sugar Added\nKosher OU-Dairy
# 8  6 Rocky Road Brownies\n12 Chocoloate Chunk Coo...
# 9  3 Layers of French Valrhona Chocolate Cake   M...
#
#                                  Product Description  Topic
# 0  A cake the dessert epicure will die for!Our To...      4
# 1  Due to the perishable nature of this item, ord...      0
# 2  Moist and buttery sponge cakes with the tradit...      4
# 3  These delectable butter pecan meltaways are th...     13
# 4  A cake the dessert epicure will die for!To the...      4
# 5  Strawberry Cheesecake: There's only one way to...     14
# 6  Once upon a time in the French coastal town of...      4
# 7  Creamy Dreamy:This smooth creamy cheesecake ha...      4
# 8  Due to the perishable nature of this product o...      4
# 9  Due to the perishable nature of this item, ord...      4

# %%
Grocery[Grocery['Sub Category'] == 'Bakery & Desserts']['Topic']
# Out:
# 0      4
# 1      0
# 2      4
# 3     13
# 4      4
# 5     14
# 6      4
# 7      4
# 8      4
# 9      4
# 10     4
# 11     4
# 12     4
# 13     4
# 14     4
# 15     4
# 16     5
# 17    13
# 18     4
# 19     4
# 20     4
# 21     4
# 22     4
# 23     4
# 24     4
# 25     4
# 26     4
# 27     4
# 28     4
# 29     4
# 30     4
# 31     0
# 32    14
# Name: Topic, dtype: int64
